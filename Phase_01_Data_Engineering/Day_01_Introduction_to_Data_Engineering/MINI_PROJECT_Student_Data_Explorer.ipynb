# %% [markdown]
# ```markdown
# # MINI PROJECT : Student Data Explorer
#
# --- Student Performance Analysis ---
# ```

# %%
import pandas as pd

df = pd.read_csv('/content/student_performance (1).csv')
df['total_score'] = df['math_score'] + df['programming_score'] + df['english_score'] + df['science_score']

print("Dataset loaded successfully and 'total_score' calculated!")
# Out:
# Dataset loaded successfully and 'total_score' calculated!

# %% [markdown]
# ```markdown
# ### 2. Dataset Overview
# ```

# %%
total_students = len(df)
print(f"Total number of students: {total_students}")

total_columns = len(df.columns)
print(f"Total number of columns: {total_columns}")

unique_departments = df['department'].nunique()
print(f"Number of unique departments: {unique_departments}")
# Out:
# Total number of students: 30
# Total number of columns: 14
# Number of unique departments: 4

# %% [markdown]
# ```markdown
# ### 3. Department wise analysis
# ```

# %%
department_counts = df['department'].value_counts()
print("Count of students in each department:")
print(department_counts)
# Out:
# Count of students in each department:
# department
# Computer Science    13
# Electronics          6
# Mechanical           6
# Civil                5
# Name: count, dtype: int64

# %% [markdown]
# ```markdown
# ### 4. Score Analysis
# ```

# %%
highest_math_score = df['math_score'].max()
lowest_math_score = df['math_score'].min()
avg_math_score = df['math_score'].mean()
avg_programming_score = df['programming_score'].mean()
avg_attendance_percentage = df['attendance_percentage'].mean()

print(f"Highest Math Score: {highest_math_score}")
print(f"Lowest Math Score: {lowest_math_score}")
print(f"Average Math Score: {avg_math_score:.2f}")
print(f"Average Programming Score: {avg_programming_score:.2f}")
print(f"Average Attendance Percentage: {avg_attendance_percentage:.2f}%")
# Out:
# Highest Math Score: 95
# Lowest Math Score: 56
# Average Math Score: 76.07
# Average Programming Score: 67.60
# Average Attendance Percentage: 84.50%

# %% [markdown]
# ```markdown
# ### 5. Gender wise Analysis
# ```

# %%
avg_total_score_by_gender = df.groupby('gender')['total_score'].mean()
print("Average Total Score by Gender:")
print(avg_total_score_by_gender)
# Out:
# Average Total Score by Gender:
# gender
# Female    310.666667
# Male      280.666667
# Name: total_score, dtype: float64

# %% [markdown]
# ```markdown
# ### 6. Top Performers
# ```

# %%
top_5_students = df.sort_values(by='total_score', ascending=False).head(5)
print("Top 5 students based on total score:")
display(top_5_students[['name', 'department', 'total_score']])
# Out:
# Top 5 students based on total score:
#               name        department  total_score
# 9       Ananya Das  Computer Science          371
# 21     Tanvi Mehta  Computer Science          367
# 29  Akanksha Yadav  Computer Science          365
# 4       Arjun Nair  Computer Science          356
# 7      Divya Singh  Computer Science          356

# %% [markdown]
# ```markdown
# ### 7. Attendance Analysis
# ```

# %%
low_attendance_students = df[df['attendance_percentage'] < 75]

if not low_attendance_students.empty:
    print("Students with attendance below 75%:")
    display(low_attendance_students[['name', 'department', 'attendance_percentage']])
else:
    print("All students have attendance above 75%.")
# Out:
# Students with attendance below 75%:
#              name   department  attendance_percentage
# 5     Meera Joshi  Electronics                     72
# 8    Rahul Mishra   Mechanical                     68
# 16   Manoj Pandey        Civil                     65
# 20  Harish Pillai  Electronics                     74
# 22   Sanjay Dubey        Civil                     70
# 27  Sunita Pillai        Civil                     73

# %% [markdown]
# ```markdown
# ### Practice Questions
# ```

# %%
electronics_students = df[df['department'] == 'Electronics'].shape[0]
print(f"1. Number of students from Electronics Department: {electronics_students}")
# Out:
# 1. Number of students from Electronics Department: 6

# %%
avg_attendance_female = df[df['gender'] == 'Female']['attendance_percentage'].mean()
print(f"2. Average attendance of female students: {avg_attendance_female:.2f}%")
# Out:
# 2. Average attendance of female students: 88.53%

# %%
lowest_programming_score_student = df.loc[df['programming_score'].idxmin()]
print("3. Student with the lowest programming score:")
print(f"   Name: {lowest_programming_score_student['name']}")
print(f"   Programming Score: {lowest_programming_score_student['programming_score']}")
# Out:
# 3. Student with the lowest programming score:
#    Name: Manoj Pandey
#    Programming Score: 38

# %%
students_math_above_80 = df[df['math_score'] > 80].shape[0]
print(f"4. Number of students who scored above 80 in math: {students_math_above_80}")
# Out:
# 4. Number of students who scored above 80 in math: 11

# %%
avg_total_score_high_attendance = df[df['attendance_percentage'] > 90]['total_score'].mean()
print(f"5. Average total score for students with attendance above 90%: {avg_total_score_high_attendance:.2f}")
# Out:
# 5. Average total score for students with attendance above 90%: 335.80
